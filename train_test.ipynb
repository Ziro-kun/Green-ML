# %%
import sys
import importlib
sys.path.append('measurement')

import train_resnet_v3
importlib.reload(train_resnet_v3)
from train_resnet_v3 import run_heavy_training

run_heavy_training(
    epochs=5, 
    batch_limit=10, 
    project_name="ResNet101-Demo-3"
)
# Out:
# 🚀 [ResNet101-Demo-3] '헤비급' 탄소 측정 시작 (ResNet-101)...
# 🏋️ cpu 장치에서 ResNet-101 모델 준비 중...
# 🔥 학습 시작 (제한: 10 배치)... 모델이 무겁습니다!
# [Step  10] 모델이 무거워 배출량이 빠르게 쌓이는 중...
# [Step  10] 모델이 무거워 배출량이 빠르게 쌓이는 중...
# [Step  10] 모델이 무거워 배출량이 빠르게 쌓이는 중...
# [Step  10] 모델이 무거워 배출량이 빠르게 쌓이는 중...
# [Step  10] 모델이 무거워 배출량이 빠르게 쌓이는 중...
#
# ...
# ✅ Training session completed. (ID: ResNet101-Demo-3)
# 🌲 Total carbon emissions: 0.001480 kg CO2
# ...
# Successfully recorded session to Local API.
