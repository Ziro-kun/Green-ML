# %%
import sys
import importlib
sys.path.append('measurement')

# Real-ESRGAN 테스트 모듈 로드
import test_realesrgan
importlib.reload(test_realesrgan)
from test_realesrgan import run_realesrgan_test

# 실행 (10회 반복)
run_realesrgan_test(project_name="Real-ESRGAN-X2Plus-Test")
